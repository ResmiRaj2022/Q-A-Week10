# %% [markdown]
# **Importing Libraries:**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# %% [markdown]
# ***1) Load the data into the pandas environment and identify some basic details of the dataset***

# %%
df = pd.read_csv("employee.csv")
df
# Out:
#             name   age   income gender  department grade  performance_score
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3                723
# 1        S Kumar   NaN  16000.0      F     Finance    G0                520
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2                674
# 3      Ying Chin  45.0  65000.0      F       Sales    G3                556
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# 5  Satyam Sharma   NaN  62000.0    NaN       Sales    G3                649
# 6   James Authur  54.0      NaN      F  Operations    G3                 53
# 7     Josh Wills  54.0  52000.0      F     Finance    G3                901
# 8       Leo Duck  23.0  98000.0      M       Sales    G4                709

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               9 non-null      object
#  1   age                7 non-null      float64
#  2   income             7 non-null      float64
#  3   gender             7 non-null      object
#  4   department         9 non-null      object
#  5   grade              9 non-null      object
#  6   performance_score  9 non-null      int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 632.0+ bytes

# %%
df.isnull().sum()
# Out:
# name                 0
# age                  2
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %% [markdown]
# **There are 2 missing Values Found  in age,income & gender columns:**

# %%
df.describe()
# Out:
#              age        income  performance_score
# count   7.000000      7.000000           9.000000
# mean   40.428571  52857.142857         610.666667
# std    12.204605  26028.372797         235.671912
# min    23.000000  16000.000000          53.000000
# 25%    31.000000  38500.000000         556.000000
# 50%    45.000000  52000.000000         674.000000
# 75%    49.500000  63500.000000         711.000000
# max    54.000000  98000.000000         901.000000

# %% [markdown]
# **The Employees are aged between 23-54**.
#
# **The Employee income ranges between 16000 - 98000**.
#
# **The Highest performance score is 901 and  the Lowest performance score is 53**.

# %% [markdown]
# ***2) Reset the index  as "name"***

# %%
df = df.set_index("name")
df
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# S Kumar         NaN  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma   NaN  62000.0    NaN       Sales    G3                649
# James Authur   54.0      NaN      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# ***3) Select rows for specific names Jack Morgan and Josh wills***

# %%
df.loc[["Jack Morgan","Josh Wills"]]
# Out:
#               age   income gender department grade  performance_score
# name
# Jack Morgan  32.0  35000.0      M    Finance    G2                674
# Josh Wills   54.0  52000.0      F    Finance    G3                901

# %% [markdown]
# ***4) Select data for multiple values "Sales" and “Finance”***

# %%
df2 = df[df["department"].isin(["Sales","Finance"])]
df2
# Out:
#                 age   income gender department grade  performance_score
# name
# S Kumar         NaN  16000.0      F    Finance    G0                520
# Jack Morgan    32.0  35000.0      M    Finance    G2                674
# Ying Chin      45.0  65000.0      F      Sales    G3                556
# Satyam Sharma   NaN  62000.0    NaN      Sales    G3                649
# Josh Wills     54.0  52000.0      F    Finance    G3                901
# Leo Duck       23.0  98000.0      M      Sales    G4                709

# %% [markdown]
# ***5) Display employee who has more than 700 performance score***

# %%
df3 = df[df["performance_score"] > 700]
df3
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# ***6) Display employee who has more than 500 and less than 700 performance score***

# %%
df4 = df[(df["performance_score"] > 500) & (df["performance_score"] < 700)]
df4
# Out:
#                 age   income gender department grade  performance_score
# name
# S Kumar         NaN  16000.0      F    Finance    G0                520
# Jack Morgan    32.0  35000.0      M    Finance    G2                674
# Ying Chin      45.0  65000.0      F      Sales    G3                556
# Satyam Sharma   NaN  62000.0    NaN      Sales    G3                649

# %% [markdown]
# ***7) Check and handle missing values in the dataset***

# %%
df.isnull().sum()
# Out:
# age                  2
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %% [markdown]
# **Handling NaN in 'AGE'**

# %%
print(df["age"].skew())
sns.distplot(df["age"])
# Out:
# -0.23573446724170385
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# In this case we can  proceed to fill the missing values with Mean/Median while age is having null values

# %%
df["age"] = df["age"].fillna(df["age"].median())
df.isna().sum()
# Out:
# age                  0
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %% [markdown]
# **Handling NaN in 'Income'**

# %%
print(df["income"].skew())
sns.distplot(df["income"])
# Out:
# 0.4963056738195404
# <AxesSubplot:xlabel='income', ylabel='Density'>

# %% [markdown]
# In this case we can  proceed to fill the missing values with Mean/Median while income is having null values

# %%
df["income"] = df["income"].fillna(df["income"].mean())
df.isna().sum()
# Out:
# age                  0
# income               0
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %%
df
# Out:
#                 age        income gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.142857    NaN  Operations    G3                723
# S Kumar        45.0  16000.000000      F     Finance    G0                520
# Jack Morgan    32.0  35000.000000      M     Finance    G2                674
# Ying Chin      45.0  65000.000000      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.000000      F  Operations    G2                711
# Satyam Sharma  45.0  62000.000000    NaN       Sales    G3                649
# James Authur   54.0  52857.142857      F  Operations    G3                 53
# Josh Wills     54.0  52000.000000      F     Finance    G3                901
# Leo Duck       23.0  98000.000000      M       Sales    G4                709

# %% [markdown]
# **Handling NaN in 'Gender'**

# %% [markdown]
# Since Gender is a categorical feature, so  we can use the Mode to fill in the missing values

# %%
df_gender = df["gender"].mode()
df_gender
# Out:
# 0    F
# Name: gender, dtype: object

# %%
df["gender"] = df["gender"].fillna("F")
df
# Out:
#                 age        income gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.142857      F  Operations    G3                723
# S Kumar        45.0  16000.000000      F     Finance    G0                520
# Jack Morgan    32.0  35000.000000      M     Finance    G2                674
# Ying Chin      45.0  65000.000000      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.000000      F  Operations    G2                711
# Satyam Sharma  45.0  62000.000000      F       Sales    G3                649
# James Authur   54.0  52857.142857      F  Operations    G3                 53
# Josh Wills     54.0  52000.000000      F     Finance    G3                901
# Leo Duck       23.0  98000.000000      M       Sales    G4                709

# %%
df.isnull().sum()
# Out:
# age                  0
# income               0
# gender               0
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %% [markdown]
# ***We have handled all the missing values in the Dataset***

# %% [markdown]
# ***8) Check the outliers and handle outliers in performance score using Percentiles***

# %%
df
# Out:
#                 age        income gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.142857      F  Operations    G3                723
# S Kumar        45.0  16000.000000      F     Finance    G0                520
# Jack Morgan    32.0  35000.000000      M     Finance    G2                674
# Ying Chin      45.0  65000.000000      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.000000      F  Operations    G2                711
# Satyam Sharma  45.0  62000.000000      F       Sales    G3                649
# James Authur   54.0  52857.142857      F  Operations    G3                 53
# Josh Wills     54.0  52000.000000      F     Finance    G3                901
# Leo Duck       23.0  98000.000000      M       Sales    G4                709

# %%
plt.figure(figsize=(8,8))
plt.boxplot(df["performance_score"])
plt.grid();

# %%
sns.kdeplot(df["performance_score"])
plt.grid()

# %%
df["performance_score"].skew()
# Out:
# -1.7947713470359914

# %%
Q1 = np.percentile(df["performance_score"],25)
Q2 = np.percentile(df["performance_score"],50)
Q3 = np.percentile(df["performance_score"],75)
IQR = Q3 - Q1
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR

print(f"The first Quartile = {Q1},\nThe Second Quartile = {Q2}, \nThe Third Quartile = {Q3}, \nIQR = {IQR}, \n\nlower limit = {lower_limit},\nupper limit = {upper_limit}")

outlier = []
for x in df["performance_score"]:
    if (x < lower_limit) or (x > upper_limit):
        outlier.append(x)
print(f"\nThe outliers are = {outlier}")

index_dropped = df[(df["performance_score"] < lower_limit) | (df["performance_score"] > upper_limit)].index
df.drop(index_dropped,inplace=True)
df
# Out:
# The first Quartile = 556.0,
# The Second Quartile = 674.0,
# The Third Quartile = 711.0,
# IQR = 155.0,
#
# lower limit = 323.5,
# upper limit = 943.5
#
# The outliers are = [53]
#                 age        income gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.142857      F  Operations    G3                723
# S Kumar        45.0  16000.000000      F     Finance    G0                520
# Jack Morgan    32.0  35000.000000      M     Finance    G2                674
# Ying Chin      45.0  65000.000000      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.000000      F  Operations    G2                711
# Satyam Sharma  45.0  62000.000000      F       Sales    G3                649
# Josh Wills     54.0  52000.000000      F     Finance    G3                901
# Leo Duck       23.0  98000.000000      M       Sales    G4                709

# %%
plt.figure(figsize=(6,5))
plt.boxplot(df["performance_score"])
plt.grid();

# %% [markdown]
# We have  now cleared the outliers in the performance score feature.

# %% [markdown]
# ***.9) Check the gender column and do Dummy encoding.***

# %%
df
# Out:
#                 age        income gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.142857      F  Operations    G3                723
# S Kumar        45.0  16000.000000      F     Finance    G0                520
# Jack Morgan    32.0  35000.000000      M     Finance    G2                674
# Ying Chin      45.0  65000.000000      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.000000      F  Operations    G2                711
# Satyam Sharma  45.0  62000.000000      F       Sales    G3                649
# Josh Wills     54.0  52000.000000      F     Finance    G3                901
# Leo Duck       23.0  98000.000000      M       Sales    G4                709

# %%
dummy_df = pd.get_dummies(df, columns=["gender"])
dummy_df
# Out:
#                 age        income  department grade  performance_score  \
# name
# Allen Smith    45.0  52857.142857  Operations    G3                723
# S Kumar        45.0  16000.000000     Finance    G0                520
# Jack Morgan    32.0  35000.000000     Finance    G2                674
# Ying Chin      45.0  65000.000000       Sales    G3                556
# Dheeraj Patel  30.0  42000.000000  Operations    G2                711
# Satyam Sharma  45.0  62000.000000       Sales    G3                649
# Josh Wills     54.0  52000.000000     Finance    G3                901
# Leo Duck       23.0  98000.000000       Sales    G4                709
#
#                gender_F  gender_M
# name
# Allen Smith           1         0
# S Kumar               1         0
# Jack Morgan           0         1
# Ying Chin             1         0
# Dheeraj Patel         1         0
# Satyam Sharma         1         0
# Josh Wills            1         0
# Leo Duck              0         1

# %% [markdown]
# ***10) Do the standard scaling on the feature performance score***

# %%
col_names = ["age","income","department","grade",'performance_score',"gender_F","gender_M"]
features = dummy_df[col_names]

# Column transforming
ct = ColumnTransformer([
        ('somename', StandardScaler(), ['performance_score'])
    ], remainder='passthrough')

ct.fit_transform(features)
# Transforming the array back into Data Frame.
x_SS= pd.DataFrame(ct.fit_transform(features))

# Re-assigning the column names and index names
x_SS.columns = ['performance_score',"age","income","department","grade","gender_F","gender_M"]
x_SS.index = ["Allen Smith","S Kumar","Jack Morgan","Ying Chin","Dheeraj Patel","Satyam Sharma","Josh Wills","Leo Duck"]
x_SS
# Out:
#               performance_score   age        income  department grade  \
# Allen Smith            0.392262  45.0  52857.142857  Operations    G3
# S Kumar               -1.475872  45.0       16000.0     Finance    G0
# Jack Morgan           -0.058667  32.0       35000.0     Finance    G2
# Ying Chin             -1.144578  45.0       65000.0       Sales    G3
# Dheeraj Patel          0.281831  30.0       42000.0  Operations    G2
# Satyam Sharma         -0.288733  45.0       62000.0       Sales    G3
# Josh Wills             2.030331  54.0       52000.0     Finance    G3
# Leo Duck               0.263425  23.0       98000.0       Sales    G4
#
#               gender_F gender_M
# Allen Smith          1        0
# S Kumar              1        0
# Jack Morgan          0        1
# Ying Chin            1        0
# Dheeraj Patel        1        0
# Satyam Sharma        1        0
# Josh Wills           1        0
# Leo Duck             0        1

# %% [markdown]
# **Performed Standard Scaling based on Performance score**
